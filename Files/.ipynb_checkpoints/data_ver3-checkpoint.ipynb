# %%
from sklearn import datasets

# %%
import pandas as pd

# %%
polymere = pd.read_csv('Exp_Mn_Mw_Value.txt', sep='\t')

# %%
polymere
# Out:
#     Run  Factor A  Factor B  Factor C  Factor D  Response 1 (Experimental)  \
# 0     1       110         7        50        10                   1127.190
# 1     2        85        13        50        10                   1024.970
# 2     3       101         1       500        60                   1950.000
# 3     4       101         1       500        60                   2223.170
# 4     5        50        10        50        10                   1845.600
# 5     6        50        10        50        10                   1846.180
# 6     7        70        10       208        60                   2073.900
# 7     8        70        10       208        60                   2074.517
# 8     9        85         1       223        60                   2298.620
# 9    10        85         1       223        60                   2298.650
# 10   11       101        10       208        60                   2322.860
# ...

# %%
X = polymere.iloc[:, 1:5].values   # columns 1 until before 5: Factor A–D
Y = polymere.iloc[:, 5:7].values   # columns 5 until before 7: Responses Mn, Mw

# %%
X.shape, Y.shape #results shows (data, input variable)(data,output)
# Out:
# ((25, 4), (25, 2))

# %%
data_cols=['Factor A','Factor B','Factor C','Factor D']

# %%
target_cols=['Response 1 (Experimental)','Response 2 (Experimental)']

# %%
X = polymere[data_cols]
Y = polymere[target_cols]

# %%
X.shape, Y.shape
# Out:
# ((25, 4), (25, 2))

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
X_train.shape, Y_train.shape #80% validation?
# Out:
# ((20, 4), (20, 2))

# %%
X_test.shape, Y_test.shape #205 for test
# Out:
# ((5, 4), (5, 2))

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

model = make_pipeline(StandardScaler(), LinearRegression())

# %%
model.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])

# %%
LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)

# %%
print('Coefficients:', model.named_steps['linearregression'].coef_)
print('Intercept:', model.named_steps['linearregression'].intercept_)
print('Mean squared error (MSE): %.2f' % mean_squared_error(Y_test, Y_pred))
print('Coefficient of determination (R^2): %.2f' % r2_score(Y_test, Y_pred))
# Out:
# Coefficients: [[-178.20876107 -499.32911196 -566.7676609   757.29811975]
#  [-265.4351073  -694.30010774 -628.26881278  790.10123855]]
# Intercept: [2503.9375 3197.76  ]
# Mean squared error (MSE): 268719.80
# Coefficient of determination (R^2): 0.79

# %%
r2_score(Y_test, Y_pred)
# Out:
# 0.7933897570694504

# %%
type(r2_score(Y_test, Y_pred))
# Out:
# float

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Y_test
# Out:
#     Response 1 (Experimental)  Response 2 (Experimental)
# 17                   3764.530                    5752.15
# 6                    2073.900                    2974.51
# 24                   2590.790                    3517.86
# 21                   1265.880                    1458.13
# 7                    2074.517                    2970.82

# %%
import numpy as np
np.array(Y_test)
# Out:
# array([[3764.53 , 5752.15 ],
#        [2073.9  , 2974.51 ],
#        [2590.79 , 3517.86 ],
#        [1265.88 , 1458.13 ],
#        [2074.517, 2970.82 ]])

# %%
Y_pred
# Out:
# array([[3581.01400789, 4518.24488212],
#        [2553.46782871, 3101.71450663],
#        [2977.79274492, 3824.53092227],
#        [1513.7046672 , 2035.25149978],
#        [2553.46782871, 3101.71450663]])
